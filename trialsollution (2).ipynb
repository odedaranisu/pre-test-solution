# %% [markdown]
# import pandas as pd
# dataset = pd.read_csv('shopping.csv');
# dataset [["Milk","Detergents_Paper","Delicassen"]]  .describe()

# %%
import pandas as pd
dataset = pd.read_csv('shopping.csv')
dataset.head()
# Out:
#    Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0        2       3  12669  9656     7561     214              2674        1338
# 1        2       3   7057  9810     9568    1762              3293        1776
# 2        2       3   6353  8808     7684    2405              3516        7844
# 3        1       3  13265  1196     4221    6404               507        1788
# 4        2       3  22615  5410     7198    3915              1777        5185

# %%
import pandas as pd
dataset = pd.read_csv('shopping.csv')
dataset.head()
print(dataset)
# Out:
#      Channel  Region  Fresh   Milk  Grocery  Frozen  Detergents_Paper  \
# 0          2       3  12669   9656     7561     214              2674
# 1          2       3   7057   9810     9568    1762              3293
# 2          2       3   6353   8808     7684    2405              3516
# 3          1       3  13265   1196     4221    6404               507
# 4          2       3  22615   5410     7198    3915              1777
# ..       ...     ...    ...    ...      ...     ...               ...
# 435        1       3  29703  12051    16027   13135               182
# 436        1       3  39228   1431      764    4510                93
# 437        2       3  14531  15488    30243     437             14841
# 438        1       3  10290   1981     2232    1038               168
# 439        1       3   2787   1698     2510      65               477
#
#      Delicassen
# 0          1338
# 1          1776
# 2          7844
# 3          1788
# 4          5185
# ..          ...
# 435        2204
# 436        2346
# 437        1867
# 438        2125
# 439          52
#
# [440 rows x 8 columns]

# %%
import pandas as pd
dataset = pd.read_csv('shopping.csv')
dataset.tail()
# Out:
#      Channel  Region  Fresh   Milk  Grocery  Frozen  Detergents_Paper  \
# 435        1       3  29703  12051    16027   13135               182
# 436        1       3  39228   1431      764    4510                93
# 437        2       3  14531  15488    30243     437             14841
# 438        1       3  10290   1981     2232    1038               168
# 439        1       3   2787   1698     2510      65               477
#
#      Delicassen
# 435        2204
# 436        2346
# 437        1867
# 438        2125
# 439          52

# %%
import pandas as pd
dataset = pd.read_csv('shopping.csv')

# %%
import pandas as pd
dataset = pd.read_csv('shopping.csv')
dataset.head()
# Out:
#    Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0        2       3  12669  9656     7561     214              2674        1338
# 1        2       3   7057  9810     9568    1762              3293        1776
# 2        2       3   6353  8808     7684    2405              3516        7844
# 3        1       3  13265  1196     4221    6404               507        1788
# 4        2       3  22615  5410     7198    3915              1777        5185

# %%
import pandas as pd

data = pd.read_csv (r'shopping.csv')
df = pd.DataFrame(data, columns= ['Milk','Detergents_Paper','Delicassen'])
print (df)
# Out:
#       Milk  Detergents_Paper  Delicassen
# 0     9656              2674        1338
# 1     9810              3293        1776
# 2     8808              3516        7844
# 3     1196               507        1788
# 4     5410              1777        5185
# ..     ...               ...         ...
# 435  12051               182        2204
# 436   1431                93        2346
# 437  15488             14841        1867
# 438   1981               168        2125
# 439   1698               477          52
#
# [440 rows x 3 columns]

# %%
#scatter plot
from matplotlib import pyplot as plt
dataset = pd.read_csv('shopping.csv')

fresh = dataset['Fresh'].tolist()
frozen = dataset['Frozen'].tolist()

#Create Scatter Plot
plt.scatter(fresh, frozen)
#Add title and axis names
plt.title('A graph of shopping')
plt.xlabel('fresh')
plt.ylabel('frozen')

# Show graphic
plt.show()

# %%
#Seaborn for correlation heatmaps with labels or annotations
#adapted from https://seaborn.pydata.org/examples/many_pairwise_correlations.html
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

#read in the pima-indians-diabetese.xlsx dataset
dataset = pd.read_csv('shopping.csv')
df = pd.DataFrame(dataset, columns= [	'Milk',	'Detergents_Paper','Delicassen'])
print (df)


#create a correlation matrix for all the column sets except the target variable
correlation = df.corr()
print("\n")
print("Pearson Standard Correlation Coefficient Matrix")
print(correlation)
print("\n")

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(correlation, dtype=bool))


#Set up matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

#Set up a seaborn heatmap
#seaborne aesthetics https://seaborn.pydata.org/tutorial/aesthetics.html
sns.set_style("white")

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

#Turn on annotations for correlation values
#annot = True
#annot_kws = {"size": 12}

# Draw the heatmap with the mask and correct aspect ratio
heatmap = sns.heatmap(correlation, mask = mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5},
            annot = True, annot_kws = {"size": 12})

#Add ticks for labels
sns.set_style({'xtick.bottom': True}, {'ytick.left': True})

#Export heatmap as an image
heatmap.get_figure().savefig('heatmap_diabetes.png', bbox_inches='tight')
# Out:
#       Milk  Detergents_Paper  Delicassen
# 0     9656              2674        1338
# 1     9810              3293        1776
# 2     8808              3516        7844
# 3     1196               507        1788
# 4     5410              1777        5185
# ..     ...               ...         ...
# 435  12051               182        2204
# 436   1431                93        2346
# 437  15488             14841        1867
# 438   1981               168        2125
# 439   1698               477          52
#
# [440 rows x 3 columns]
#
#
# Pearson Standard Correlation Coefficient Matrix
#                       Milk  Detergents_Paper  Delicassen
# Milk              1.000000          0.661816    0.406368
# Detergents_Paper  0.661816          1.000000    0.069291
# Delicassen        0.406368          0.069291    1.000000
